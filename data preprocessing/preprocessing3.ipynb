# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Extracting features of 2018 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1=pd.read_html(link,header=0)[2]
df2=pd.read_html(link,header=0)[3]
df3=pd.read_html(link,header=0)[4]
df4=pd.read_html(link,header=0)[5]

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 267  [164]
# 268  [137]
# 269  [228]
# 270  [260]
# 271  [261]
#
# [272 rows x 7 columns]

# %%
pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in s:\anaconda\lib\site-packages (1.7.7)
# Requirement already satisfied: requests in s:\anaconda\lib\site-packages (from tmdbv3api) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in s:\anaconda\lib\site-packages (from requests->tmdbv3api) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in s:\anaconda\lib\site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in s:\anaconda\lib\site-packages (from requests->tmdbv3api) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in s:\anaconda\lib\site-packages (from requests->tmdbv3api) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb=TMDb()
tmdb.api_key='5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie=Movie()
def get_genre(x):
    genres=[]
    result = tmdb_movie.search(x)
    movie_id=result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return " ".join(genres)
    else:
        np.NaN

# %%
df['genres']=df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref.                                           genres
# 0      NaN                          Horror Mystery Thriller
# 1      NaN                                   Thriller Drama
# 2      NaN                                  Action Thriller
# 3      NaN                            Drama History Western
# 4      NaN                          Action Thriller Mystery
# ..     ...                                              ...
# 267  [164]                   Mystery Adventure Comedy Crime
# 268  [137]        Thriller Science Fiction Action Adventure
# 269  [228]                                    Drama History
# 270  [260]                      Thriller Crime Drama Action
# 271  [261]  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 8 columns]

# %%
df_2018 = df[['genres','Cast and crew','Title']]

# %%
df_2018
# Out:
#                                               genres  \
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                           Title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name']=df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/2003605963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name']=df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018
# Out:
#                                               genres  \
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                           Title       director_name     actor_1_name  \
# 0       Insidious: The Last Key        Adam Robitel        Lin Shaye
# 1              The Strange Ones    Lauren Wolkstein    Alex Pettyfer
# 2                      Stratton          Simon West   Dominic Cooper
# 3                 Sweet Country    Warwick Thornton      Bryan Brown
# 4                  The Commuter  Jaume Collet-Serra      Liam Neeson
# ..                          ...                 ...              ...
# 267             Holmes & Watson          Etan Cohen     Will Ferrell
# 268                        Vice          Adam McKay   Christian Bale
# 269         On the Basis of Sex          Mimi Leder   Felicity Jones
# 270                   Destroyer        Karyn Kusama    Nicole Kidman
# 271  Black Mirror: Bandersnatch         David Slade  Fionn Whitehead
#
#                actor_2_name    actor_3_name
# 0             Angus Sampson  Leigh Whannell
# 1    James Freedson-Jackson   Emily Althaus
# 2            Austin Stowell      Gemma Chan
# 3                 Sam Neill             NaN
# 4              Vera Farmiga  Patrick Wilson
# ..                      ...             ...
# 267          John C. Reilly    Rebecca Hall
# 268               Amy Adams    Steve Carell
# 269            Armie Hammer  Justin Theroux
# 270          Sebastian Stan    Toby Kebbell
# 271            Will Poulter   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['Cast and crew'][1]
# Out:
# 'Lauren Wolkstein (director); Christopher Radcliff (co-director/screenplay); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell'

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/2517195254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                                               genres  \
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                           Title       director_name     actor_1_name  \
# 0       Insidious: The Last Key        Adam Robitel        Lin Shaye
# 1              The Strange Ones    Lauren Wolkstein    Alex Pettyfer
# 2                      Stratton          Simon West   Dominic Cooper
# 3                 Sweet Country    Warwick Thornton      Bryan Brown
# 4                  The Commuter  Jaume Collet-Serra      Liam Neeson
# ..                          ...                 ...              ...
# 267             Holmes & Watson          Etan Cohen     Will Ferrell
# 268                        Vice          Adam McKay   Christian Bale
# 269         On the Basis of Sex          Mimi Leder   Felicity Jones
# 270                   Destroyer        Karyn Kusama    Nicole Kidman
# 271  Black Mirror: Bandersnatch         David Slade  Fionn Whitehead
#
#                actor_2_name    actor_3_name
# 0             Angus Sampson  Leigh Whannell
# 1    James Freedson-Jackson   Emily Althaus
# 2            Austin Stowell      Gemma Chan
# 3                 Sam Neill             NaN
# 4              Vera Farmiga  Patrick Wilson
# ..                      ...             ...
# 267          John C. Reilly    Rebecca Hall
# 268               Amy Adams    Steve Carell
# 269            Armie Hammer  Justin Theroux
# 270          Sebastian Stan    Toby Kebbell
# 271            Will Poulter   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['genres','actor_1_name','actor_2_name','actor_3_name','movie_title','director_name']]

# %%
new_df18
# Out:
#                                               genres     actor_1_name  \
# 0                            Horror Mystery Thriller        Lin Shaye
# 1                                     Thriller Drama    Alex Pettyfer
# 2                                    Action Thriller   Dominic Cooper
# 3                              Drama History Western      Bryan Brown
# 4                            Action Thriller Mystery      Liam Neeson
# ..                                               ...              ...
# 267                   Mystery Adventure Comedy Crime     Will Ferrell
# 268        Thriller Science Fiction Action Adventure   Christian Bale
# 269                                    Drama History   Felicity Jones
# 270                      Thriller Crime Drama Action    Nicole Kidman
# 271  Science Fiction Mystery Drama Thriller TV Movie  Fionn Whitehead
#
#                actor_2_name    actor_3_name                 movie_title  \
# 0             Angus Sampson  Leigh Whannell     Insidious: The Last Key
# 1    James Freedson-Jackson   Emily Althaus            The Strange Ones
# 2            Austin Stowell      Gemma Chan                    Stratton
# 3                 Sam Neill             NaN               Sweet Country
# 4              Vera Farmiga  Patrick Wilson                The Commuter
# ..                      ...             ...                         ...
# 267          John C. Reilly    Rebecca Hall             Holmes & Watson
# 268               Amy Adams    Steve Carell                        Vice
# 269            Armie Hammer  Justin Theroux         On the Basis of Sex
# 270          Sebastian Stan    Toby Kebbell                   Destroyer
# 271            Will Poulter   Asim Chaudhry  Black Mirror: Bandersnatch
#
#           director_name
# 0          Adam Robitel
# 1      Lauren Wolkstein
# 2            Simon West
# 3      Warwick Thornton
# 4    Jaume Collet-Serra
# ..                  ...
# 267          Etan Cohen
# 268          Adam McKay
# 269          Mimi Leder
# 270        Karyn Kusama
# 271         David Slade
#
# [272 rows x 6 columns]

# %%
nan_val = [features for features in new_df18.columns if new_df18[features].isna().sum()]

# %%
nan_val
# Out:
# ['genres', 'actor_2_name', 'actor_3_name']

# %%
for feature in nan_val:
    print(feature,'having',np.round(new_df18[feature].isnull().mean(),2), '% missing values')
# Out:
# genres having 0.0 % missing values
# actor_2_name having 0.04 % missing values
# actor_3_name having 0.1 % missing values

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title']=new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#                                               genres     actor_1_name  \
# 0                            Horror Mystery Thriller        Lin Shaye
# 1                                     Thriller Drama    Alex Pettyfer
# 2                                    Action Thriller   Dominic Cooper
# 3                              Drama History Western      Bryan Brown
# 4                            Action Thriller Mystery      Liam Neeson
# ..                                               ...              ...
# 267                   Mystery Adventure Comedy Crime     Will Ferrell
# 268        Thriller Science Fiction Action Adventure   Christian Bale
# 269                                    Drama History   Felicity Jones
# 270                      Thriller Crime Drama Action    Nicole Kidman
# 271  Science Fiction Mystery Drama Thriller TV Movie  Fionn Whitehead
#
#                actor_2_name    actor_3_name                 movie_title  \
# 0             Angus Sampson  Leigh Whannell     insidious: the last key
# 1    James Freedson-Jackson   Emily Althaus            the strange ones
# 2            Austin Stowell      Gemma Chan                    stratton
# 3                 Sam Neill         unknown               sweet country
# 4              Vera Farmiga  Patrick Wilson                the commuter
# ..                      ...             ...                         ...
# 267          John C. Reilly    Rebecca Hall             holmes & watson
# 268               Amy Adams    Steve Carell                        vice
# 269            Armie Hammer  Justin Theroux         on the basis of sex
# 270          Sebastian Stan    Toby Kebbell                   destroyer
# 271            Will Poulter   Asim Chaudhry  black mirror: bandersnatch
#
#           director_name                                               comb
# 0          Adam Robitel  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1      Lauren Wolkstein  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2            Simon West  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3      Warwick Thornton  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Jaume Collet-Serra  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                  ...                                                ...
# 267          Etan Cohen  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268          Adam McKay  Christian Bale Amy Adams Steve Carell Adam McK...
# 269          Mimi Leder  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270        Karyn Kusama  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271         David Slade  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [272 rows x 7 columns]

# %% [markdown]
# # Extracting features of 2019 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 237  20th Century Fox / Blue Sky Studios / Chernin ...
# 238            Columbia Pictures / Regency Enterprises
# 239           Universal Pictures / DreamWorks Pictures
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 237  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [222]
# 240  Destin Daniel Cretton (director/screenplay), A...  [223]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [224]
#
# [242 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Shaik Siddiq\AppData\Local\Temp/ipykernel_6408/3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 237  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 238            Greta Gerwig        Saoirse Ronan           Emma Watson
# 239              Sam Mendes        George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                    Horror Comedy Thriller
# 1        Sean O'Bryan                            Thriller Drama
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 237     Rashida Jones  Animation Action Adventure Comedy Family
# 238     Florence Pugh                     Drama Romance History
# 239       Mark Strong         War Drama Action Thriller History
# 240       Brie Larson                       Drama Crime History
# 241       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 237  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 238       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 240         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [242 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#                                        genres       actor_1_name  \
# 0                     Horror Mystery Thriller          Lin Shaye
# 1                              Thriller Drama      Alex Pettyfer
# 2                             Action Thriller     Dominic Cooper
# 3                       Drama History Western        Bryan Brown
# 4                     Action Thriller Mystery        Liam Neeson
# ..                                        ...                ...
# 509  Animation Action Adventure Comedy Family         Will Smith
# 510                     Drama Romance History      Saoirse Ronan
# 511         War Drama Action Thriller History      George MacKay
# 512                       Drama Crime History  Michael B. Jordan
# 513                                     Drama      Alfre Woodard
#
#                actor_2_name    actor_3_name              movie_title  \
# 0             Angus Sampson  Leigh Whannell  insidious: the last key
# 1    James Freedson-Jackson   Emily Althaus         the strange ones
# 2            Austin Stowell      Gemma Chan                 stratton
# 3                 Sam Neill         unknown            sweet country
# 4              Vera Farmiga  Patrick Wilson             the commuter
# ..                      ...             ...                      ...
# 509             Tom Holland   Rashida Jones        spies in disguise
# 510             Emma Watson   Florence Pugh             little women
# 511    Dean-Charles Chapman     Mark Strong                     1917
# 512              Jamie Foxx     Brie Larson               just mercy
# 513          Wendell Pierce     Aldis Hodge                 clemency
#
#               director_name                                               comb
# 0              Adam Robitel  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1          Lauren Wolkstein  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2                Simon West  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3          Warwick Thornton  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4        Jaume Collet-Serra  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                      ...                                                ...
# 509  Nick Bruno, Troy Quane  Will Smith Tom Holland Rashida Jones Nick Brun...
# 510            Greta Gerwig  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 511              Sam Mendes  George MacKay Dean-Charles Chapman Mark Strong...
# 512   Destin Daniel Cretton  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 513         Chinonye Chukwu  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [514 rows x 7 columns]

# %%
old_df=pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     Action Adventure Fantasy Sci-Fi CCH PounderJoe...
# 1     Action Adventure Fantasy Johnny DeppOrlando Bl...
# 2     Action Adventure Thriller Christoph WaltzRory ...
# 3     Action Thriller Tom HardyChristian Bale Joseph...
# 4     Documentary Doug WalkerRob Walker unknown star...
# ...                                                 ...
# 5359  Romance Comedy Jessica WilliamsChris O'Dowd Ke...
# 5360  Romance Adelaide KaneBenjamin Hollingsworth Je...
# 5361  Romance Comedy Inka HaapamäkiRosa Honkonen Tii...
# 5362  Crime Comedy Action Family Lou Diamond Phillip...
# 5363  Crime Drama Thriller Sridevi KapoorSajal Ali A...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5873  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5874            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5875              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5876   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5877         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5873         Rashida Jones  Animation Action Adventure Comedy Family
# 5874         Florence Pugh                     Drama Romance History
# 5875           Mark Strong         War Drama Action Thriller History
# 5876           Brie Larson                       Drama Crime History
# 5877           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5873                                  spies in disguise
# 5874                                       little women
# 5875                                               1917
# 5876                                         just mercy
# 5877                                           clemency
#
#                                                    comb
# 0     Action Adventure Fantasy Sci-Fi CCH PounderJoe...
# 1     Action Adventure Fantasy Johnny DeppOrlando Bl...
# 2     Action Adventure Thriller Christoph WaltzRory ...
# 3     Action Thriller Tom HardyChristian Bale Joseph...
# 4     Documentary Doug WalkerRob Walker unknown star...
# ...                                                 ...
# 5873  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5874  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5875  George MacKay Dean-Charles Chapman Mark Strong...
# 5876  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5877  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5878 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           1
# movie_title      0
# comb             1
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index =False)
